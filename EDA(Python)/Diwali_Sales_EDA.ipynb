# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Diwali Sales Data.csv', encoding = 'unicode_escape')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(['Status', 'unnamed1'], axis = 1, inplace = True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df['Amount'] = df['Amount'].astype('int')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns = {'Cust_name' : 'Customer_Name'})
# Out:
#        User_ID Customer_Name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903     Sanskriti  P00125942      F     26-35   28               0
# 1      1000732        Kartik  P00110942      F     26-35   35               1
# 2      1001990         Bindu  P00118542      F     26-35   35               1
# 3      1001425        Sudevi  P00237842      M      0-17   16               0
# 4      1000588          Joni  P00057942      M     26-35   28               1
# ...        ...           ...        ...    ...       ...  ...             ...
# 11246  1000695       Manning  P00296942      M     18-25   19               1
# 11247  1004089   Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209         Oshin  P00201342      F     36-45   40               0
# 11249  1004023        Noonan  P00059442      M     36-45   37               0
# 11250  1002744       Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# Gender

# %%
ax = sns.countplot(x = 'Gender', data = df)
for i in ax.containers:
    ax.bar_label(i)

# %%
sales_by_gen = df.groupby(['Gender'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending = False)
sales_by_gen
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
bx = sns.barplot(x = 'Gender', y = 'Amount', data = sales_by_gen)

# %% [markdown]
# *The data shows a higher concentration of female buyers, and their overall purchasing power surpasses that of male buyers.*

# %% [markdown]
# Age

# %%
ax = sns.countplot(x = 'Age Group', data = df, hue = 'Gender')
for i in ax.containers:
    ax.bar_label(i)

# %%
sales_by_age = df.groupby(['Age Group'], as_index = False)['Amount'].sum().sort_values(by = ['Amount'], ascending = False)
sns.barplot(x = 'Age Group', y = 'Amount', data = sales_by_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# *The graphs show a notable concentration of female buyers within the 26-35 age group.*

# %% [markdown]
# State

# %%
sales_by_state = df.groupby(['State'], as_index = False)['Orders'].sum().sort_values(by = ['Orders'], ascending = False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.barplot(data = sales_by_state, x = 'State',y= 'Orders')

for i in ax.containers:
    ax.bar_label(i)

# %%
sales_by_state = df.groupby(['State'], as_index = False)['Amount'].sum().sort_values(by = ['Amount'], ascending = False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.barplot(data = sales_by_state, x = 'State',y= 'Amount')

# %% [markdown]
# *The graphs show a clear concentration of both orders and total sales/amount in Uttar Pradesh, Maharashtra, and Karnataka.*

# %% [markdown]
# Marital Status

# %%
ax = sns.countplot(x = 'Marital_Status', data = df)
sns.set(rc = {'figure.figsize' : (5,7)})
for i in ax.containers:
    ax.bar_label(i)

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# *The graphs show a high concentration of female buyers who are married, and their spending power surpasses that of other groups.*

# %% [markdown]
# Occupation

# %%
sns.set(rc = {'figure.figsize' : (15,5)})
ax = sns.countplot(x = 'Occupation', data = df)

for i in ax.containers:
    ax.bar_label(i)

# %%
sales_by_occu = df.groupby(['Occupation'], as_index = False)['Amount'].sum().sort_values(by = ['Amount'], ascending = False)
sns.set(rc = {'figure.figsize' : (15,5)})
sns.barplot(x = 'Occupation', y = 'Amount', data = sales_by_occu)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *The graphs reveal a significant presence of buyers within the IT, Healthcare, and Aviation sectors.*

# %% [markdown]
# Product Category

# %%
sns.set(rc = {'figure.figsize' : (30,5)})
ax = sns.countplot(x = 'Product_Category', data = df)

for i in ax.containers:
    ax.bar_label(i)

# %%
sales_by_cate = df.groupby(['Product_Category'], as_index = False)['Amount'].sum().sort_values(by = ['Amount'], ascending = False).head(10)
sns.set(rc = {'figure.figsize' : (20, 5)})
sns.barplot(x = 'Product_Category', y = 'Amount', data = sales_by_cate)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *The graphs show a dominant share of sales within the Food, Clothing, and Electronics categories.*

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
ax1.set_xlabel("Product ID")
ax1.set_ylabel("Number of Orders")
# Out:
# Text(0, 0.5, 'Number of Orders')

# %% [markdown]
# Conclusion

# %% [markdown]
# **Married women between the ages of 26 and 35 residing in Uttar Pradesh, Maharashtra, and Karnataka, and employed in the IT, Healthcare, and Aviation sectors, exhibit a greater likelihood of purchasing products from the Food, Clothing, and Electronics categories.**
